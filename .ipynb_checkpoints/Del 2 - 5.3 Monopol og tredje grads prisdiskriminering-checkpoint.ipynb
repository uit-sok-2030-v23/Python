# %% [markdown]
# # Sok-2030 Næringsøkonomi og konkuransestrategi
# ## Del 2 Monopol og prisdiskriminering
# ### Optimal tilpasning ved tredje grads prisdiskriminering

# %%
import sympy as sp
import numpy as np
from matplotlib import pyplot as plt

# %%
def demand(Q):
    return 30-2*Q

# %%
def marginalrevenue(Q):
    return 30-4*Q

# %%
def marginalcost(Q):
    return 4

# %%
Q=sp.symbols('Q', real=True, positive=True)
equ=sp.Eq(marginalrevenue(Q),marginalcost(Q))
equ
# Out:
# Eq(30 - 4*Q, 4)

# %% [markdown]
# ## Optimal tilpasning ved linear prising:

# %%
Q_equ=sp.solve(equ,Q)[0]
Q_equ
round(Q_equ,2)
# Out:
# 6.50

# %%
p_eq=demand(Q_equ)
p_eq
# Out:
# 17

# %%
# salg i USA - demand P = 36 -4Qu
def Q(P):
    return 9-P/4
print(Q(17))
# Out:
# 4.75

# %%
# salg i Europa - demand P = 24 -4Qu
def Q(P):
    return 6-P/4
print(Q(17))
# Out:
# 1.75

# %%
# Marginalinntekt USA - P = 36 -8Qu
def MR(Q):
    return 36-8*Q
print(MR(4.75))
# Out:
# -2.0

# %%
# Marginalinntekt Europa P = 24 -8Qu
def MR(Q):
    return 24-8*Q
print(MR(1.75))
# Out:
# 10.0

# %%
# Profitt
def profitt(Q):
    return (p_eq-marginalcost(Q))*Q_equ
print (profitt(Q_equ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 def profitt(Q):
#       3     return (p_eq-marginalcost(Q))*Q_equ
# ----> 4 print (profitt(Q_equ))
#
# Cell In[13], line 3, in profitt(Q)
#       2 def profitt(Q):
# ----> 3     return (p_eq-marginalcost(Q))*Q_equ
#
# NameError: name 'p_eq' is not defined

# %% [markdown]
# ### Optimal tilpasning ved tredje grads prisdiskriminering:

# %% [markdown]
# Tilpasning USA

# %%
#  USA - demand P = 36 -4Qu
def demand(Qu):
    return 36-4*Qu

# %%
# Marginalinntekt USA - P = 36 -8Qu
def marginalrevenue(Qu):
    return 36-8*Qu

# %%
def marginalcost(Qu):
    return 4

# %%
Qu=sp.symbols('Qu', real=True, positive=True)
equ=sp.Eq(marginalrevenue(Qu),marginalcost(Qu))
equ
# Out:
# Eq(36 - 8*Qu, 4)

# %%
# optimal valg av antall bøker i USA
Qu_equ=sp.solve(equ,Qu)[0]
Qu_equ
# Out:
# 4

# %%
# optimal pris på bøker i USA
pu_eq=demand(Qu_equ)
pu_eq
# Out:
# 20

# %%
# Profitt USA
def profitt(Qu):
    return (20-4)*Qu
print (profitt(4))
# Out:
# 64

# %% [markdown]
# Tilpasning Eurpoa

# %%
#  Europa - demand P = 36 -4Qe
def demand(Qe):
    return 24-4*Qe

# %%
# Marginalinntekt Europa - P = 24 -8Qe
def marginalrevenue(Qe):
    return 24-8*Qe

# %%
def marginalcost(Qe):
    return 4

# %%
Qe=sp.symbols('Qe', real=True, positive=True)
equ=sp.Eq(marginalrevenue(Qe),marginalcost(Qe))
equ
# Out:
# Eq(24 - 8*Qe, 4)

# %%
# optimal valg av antall bøker i Europa
Qe_equ=sp.solve(equ,Qe)[0]
Qe_equ
round(Qe_equ,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # optimal valg av antall bøker i Europa
# ----> 2 Qe_equ=sp.solve(equ,Qe)[0]
#       3 Qe_equ
#       4 round(Qe_equ,2)
#
# NameError: name 'Qe' is not defined

# %%
# optimal pris på bøker i Europa
pe_eq=demand(Qe_equ)
pe_eq
# Out:
# 14

# %%
# Profitt Europa
def profitt(Qe):
    return (14-4)*Qe
print (profitt(2.5))
# Out:
# 25.0
